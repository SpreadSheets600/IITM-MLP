# %% [markdown]
# #Metadata
# The dataset contains 10000 records and 12 variables, each described below:
#
# | Column         | Description                                               |
# |----------------|----------------------------------------------------------|
# | age            | Age in days                                              |
# | height         | Height in centimeters (cm)                               |
# | weight         | Weight in kilograms (kg)                                 |
# | gender         | Gender (male, female)      |
# | systolic_pressure         | Systolic blood pressure (mm Hg)                          |
# | Diastolic_pressure          | Diastolic blood pressure (mm Hg)                         |
# | cholesterol    | Cholesterol level (normal, above normal, well above normal) |
# | gluc           | Glucose level ( normal, above normal, well above normal)     |
# | smoke          | Smoking status (Yes, No)                |
# | alco           | Alcohol intake (Doesn't Drink, Drink                         |
# |physical_activity        | Physical activity (inactive, active) |
# | cardio         | Presence of cardiovascular disease (target; 0: no, 1: yes)|

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ### Q1. [marks : 0] Which dataset are you using for this exam? Dataset contains 10000 rows
#
# Options:
#
# A) MLP_OPPE2_25T3_preprocessing_V1
#
# B) MLP_OPPE2_25T3_preprocessing_V2
#
# C) MLP_OPPE2_25T3_preprocessing_V3

# %% [markdown]
# ### Q2 [Marks:5] In this dataset, what is the 2nd most frequent category in the “cholesterol” feature?
#
# (A) normal \
# (B) above normal \
# (C) well above normal

# %% [markdown]
# ### Q3 [Marks:5] What is the ratio of counts of individuals who are “Active” to those who are “Inactive” among individuals who meet all the following criteria:
# 	•	Gender = “Women”
# 	•	cholesterol = “well above normal”
# 	•	Age (in years) > 60 (age / 365 > 60)
#
#
# (A) 182 : 44
#
# (B) 183 : 38
#
# (C) 181 : 43
#
# (D) 181 : 33

# %% [markdown]
# ### Q4 [Marks:5] Which of the following option(s) are true?
#
# (A) The average age (in years) for individuals with glucose_level = “well above normal” falls within the range of 52 to 56.
#
# (B) The average weight for individuals who are “Inactive” falls within the range of 65 to 75 kg.
#
# (C) The average Diastolic_pressure for individuals with cholesterol = “well above normal” falls within the range of 85 to 95 mm Hg.
#
# (D) The average systolic_pressure for “Women” who are “Active” falls within the range of 120 to 130 mm Hg.
#
# (E) None of these

# %% [markdown]
# ### Q5 [Marks:5] Create a feature matrix (X) and label vector (y) using the following instructions:
# 	•	cardio_disease is the target column (y).
# 	•	All columns except the target are in feature matrix (X).
#
# Compare the correlation value for the following feature pairs of feature matrix (X) and select the option which has the highest positive value.
#
# (A) age vs weight
#
# (B) height vs weight
#
# (C) systolic_pressure vs Diastolic_pressure
#
# (D) age vs systolic_pressure
#
# (E) height vs age

# %% [markdown]
# ### Q6 [Marks:5] Split the dataset into train and test sets in the following manner:
# 	•	Use sklearn train_test_split function to split the data.
# 	•	Use only 20% data as test set and keep random_state = 24.
#
# What is the sum of cardio_disease (target) column in the test set?

# %% [markdown]
# ### Following all the questions are related to the **Data Preprocessing** you have to apply and save the preprocessing steps and move further.
#
# ## Common Instructions for Question 7 to 9
# ## Rules for Imputing the missing(NaN) or Unknown values:
# - Calculating statistical values (such as mean, median, mode) for each column in the training dataset.
# - Applying these calculated statistical values to replace missing (NaN) and unknown values in both the training and test datasets.
# - Ensuring that the calculation of statistical values excludes any rows containing missing or unknown values.
# - After imputation store the dataframe in another variable imputed_df
#
# - Replace the missing values in the **systolic_pressure** feature with the **Mean** value in that.
#
# - Replace the missing values in the **Diastolic_pressure** feature with the **Mean** value in that.
#
# - Replace the missing values in the **cholesterol** feature with the **Constant** value 'normal'. (case sensitive)
#
# - Replace the missing values in the **glucose_level** feature with the **Constant** value 'normal'. (case sensitive)
#
# - Replace the missing values in the **alcohol** feature with the **Constant** value 'Doesn't Drink'. (case sensitive)
#
#
# - Write the answers related to the above imputation in below questions respectively.

# %% [markdown]
# ### Q7 [Marks: 5] Write the MEAN value of the **systolic_pressure** column of the train dataset after you have replaced all the Missing Values (NaN). [NAT] (upto 2 digits after decimal points)

# %% [markdown]
# ### Q8 [Marks: 5] Write the MEAN value of the **Diastolic_pressure** column of the train dataset you found to replace all the Missing Values (NaN). [NAT] (correct upto 2 digits after decimal points)

# %% [markdown]
# ### Q9 [Marks: 5] Write the 2nd MOST FREQUENT value of the **glucose_level** column of the train dataset after replacing all the Missing Values (NaN) with constant.
#
# (A) normal \
# (B) above normal \
# (C) well above normal

# %% [markdown]
# ## Apply preprocessing on features of train and test datasets.
#
# - After applying the above imputation steps there should not be any missing or unknown values present in the train and test dataset.
#
# - fitting (learning) should be done only on train dataset after above imputation is done.
#
# - Learn transformers' parameters using training set only and then apply them on train & test sets.
#
# ## For Categorical Features
#
# Ordinally Encode **"cholesterol"** features as Order given in table below
#
# |cholesterol|Order|
# |-------|--------|
# |normal|0|
# |above normal|1|
# |well above normal|2|
#
# Ordinally Encode **"glucose_level"** features as Order given in table below
#
# |glucose_level|Order|
# |-------|--------|
# |normal|0|
# |above normal|1|
# |well above normal|2|
#
# ### Nominal Features
# - One-Hot Encode **"gender", "smoke", "alcohol", "active"** features and keep drop_first = True.
#
#
# ### Scaling Features
# * Scale **all the features** (transformed categorical and numerical) of the feature matrix using the **StandardScaler**

# %% [markdown]
# ###Q10 [Marks:3][NAT] Calculate the sum of all the values present in the transformed train feature matrix ? (upto 2 digits afer the decimal)

# %% [markdown]
# ###Q11 [Marks:7][NAT] Calculate the sum of all the values present in the transformed test feature matrix ? (upto 2 digits afer the decimal)

# %% [markdown]
# #ModelBuilding [Marks: 50]
#
# ## Instruction
# - **Set or change** the parameters specified in the question, while keeping all other parameters at their default values.

# %% [markdown]
# ### Q1. [marks : 0] Which dataset are you using for this Model Building section? Dataset contains 10000 rows.
#
# Options:
#
# (A) MLP_OPPE2_25T3_modelBuilding_V1
#
# (B) MLP_OPPE2_25T3_modelBuilding_V2
#
# (C) MLP_OPPE2_25T3_modelBuilding_V3

# %% [markdown]
# ### Split the dataset into train dataset and test dataset in the following manner.
# - **cardio_disease** is the target column(y).
# - All the columns except the target column are in feature matrix(X).
# - Use sklearn train_test_split function to split the data.
# - Use only 20% data as test_set and keep random_state = 42

# %% [markdown]
# ### Q2 [5 marks][NAT] Take **`LogisticRegression`** estimator with following parameters for training:
#   - Use `sag` as solver
#   - Set random state to be equal to 42
#   - Tolerance for stopping criteria to be 1e-3
#   - Maximum number of iterations taken for the solvers to converge to be 200
#
# ### **Enter the number of iteration required for the given model to converge using train set(X_train, y_train)**

# %% [markdown]
# ### Q3  [6 marks] [NAT] Use **`SGDClassifier`** on the training dataset (**`X_train`** and **`y_train`**) to train the model. Use the following parameters:
#
# 1. `log_loss`is the loss function to be used
# 2. apply ridge regularization,
# 3. maximum number of passes over the training data is 30
# 4. Initial learning rate of 0.01
# 5. regularization rate value is 0.001,
# 6. Take random_state=42.
# 7. Set warm_start as True
#
# Note : Please ignore the convergence warning.
#
# ### **Using above model, calculate and write the correct value of f1_score for label class = 0 of the test set.**

# %% [markdown]
# ### **Q4. [6 marks] [MCQ] For the training dataset tune the parameters using Gridsearchcv for below settings**
# - `estimator = KNeighborsClassifier`
# - `scoring =accuracy`
# - `cv= 5`
# * Consider following parameters for KNeighborsClassifier:
#  - `n_neighbors = [11,17,23,29]`
#  - `metric = "minkowski"`
#  - Set p value for `minkowski = 2`
#
# - Keep other parameter values as default values.
#
# ### **What is the best value of K you obtained using the above instructions?**
#
# Options
#
# (A) 11
#
# (B) 17
#
# (C) 23
#
# (D) 29

# %% [markdown]
# ### **Q.5 [3 Marks] [MCQ] Fit an SVM classifier (SVC) with the following parameters:**
#
# - `kernel='rbf'`
# - `decision_function_shape='ovr'`
# - `random_state=42`
# - `C=1`
#
# ###**Train the model on training data, and choose the option with correct classification confusion matrix on test data.**
#
# (A)$\begin{bmatrix} %V2
#  714  & 302\\
#  327 & 657
#  \end{bmatrix}$
# \
# \
# (B) $\begin{bmatrix} %V1
#  786  & 221\\
#  352 & 641
#  \end{bmatrix}$
# \
# \
# (C) $\begin{bmatrix} %
# 1523 & 69 \\
# 142 & 266
#  \end{bmatrix}$
# \
# \
# (D)$\begin{bmatrix} %V3
#  781 &  250\\
#  304 & 665
#  \end{bmatrix}$
# \
# \
# (E) None of the above

# %% [markdown]
# **Common Instruction for Question 6 to 8**
#
# Train a Decision Tree Classifier on the training data with the following parameters:
#
# - `criterion = 'entropy'`
# - `splitter = 'random'`
# - `min_samples_split = 3`
# - `min_impurity_decrease = 0.0001`
# - `random_state = 42`
#
# ###**Q.6 [NAT][3 Marks] What is the depth of the trained tree?**

# %% [markdown]
# ###**Q.7 [NAT][3 Marks] How many nodes are there in the tree?**

# %% [markdown]
# ###**Q.8 [NAT][5 Marks] What is the value of entropy at the root node?** (correct upto 3 digit after decimal)

# %% [markdown]
# ### **(Common Instructions for Q9,Q10)**
# ##Train an AdaBoost Classifier model on the training data using the specified hyperparameter values below and optimize it with GridSearchCV
# - Use n_estimators as [13,29,37]
# - random_state = 42
# - Use learning_rate as [0.001,0.01,1,2]
# - use 5 fold cross validation

# %% [markdown]
# ###**Q9[Marks: 5][MCQ] Choose the value of `n_estimators` of the best model after training with GridSearchCV.**
#
# Options:
#
# (A) 13
#
# (B) 29
#
# (C) 37
#
# (D) None of these

# %% [markdown]
# ###**Q10[Marks: 5] [NAT] Train the 'model' using above instructions and use the best estimator to calculate the total number of misclassified samples in test data for which label was 1 (i.e. y_test=1) and submit the value.**

# %% [markdown]
# ### **Q11. [Marks: 5 ] [NAT] Train  with RandomizedSearchCV.**
#
# - Keep Below Settings for **`RandomForestClassifier(random_state=42)`** estimator
#   - n_estimators = range(2,100)
#   - max_depth = range(1,11)
#   - min_impurity_decrease = uniform(loc=0,scale=5)
#
#
# - Keep below settings for RandomizedSearchCV
#   - estimator = RandomForestClassifier(random_state=42)
#   - random_state = 42
#   - n_iter=5
#   - cv=3
#   - n_jobs= -1
#   - verbose=2
#
# hint: from scipy.stats import uniform
#
# ###**Submit the best param value for n_estimators using this RandomizedSearchCV on train data.**

# %% [markdown]
# ###**Q12[Marks 4] [NAT] Write the accuray score of the test dataset using the best model** (upto 3 digit after the decimal)
